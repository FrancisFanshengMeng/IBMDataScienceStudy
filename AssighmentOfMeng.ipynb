# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Fansheng Meng__
#
# I am a software engineer now, want to be a data scientist in the future.

# %% [markdown]
# *I am intrested in data sience, and good at maths and statistic*.
#
# *Data should be the center of the world. I wish I can find the problem from data, predict things from data, and find chances from data*.
#
# *I hope these cources can help me succesful*.

# %% [markdown]
# ### Followed is a simple python code, it should print something...

# %%
str1 = "Hello"
str2 = " Meng,"
str3 = " wellcome to IBM Waston Studio."
print(str1+str2+str3)
# Out:
# Hello Meng, wellcome to IBM Waston Studio.

# %% [markdown]
# ***MyGoal***
#
# 1. Pass all the courses in 3 months.
# 2. Find a project to pactice.
# 3. Find a job of data scince with 1 year.
#
# >  *Everything* is going according to **plan**.
#
# link of the course: <https://www.coursera.org>
#
# Please contact me at : <mfsheng@gmail.com>
